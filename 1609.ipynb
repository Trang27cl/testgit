# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox

def selection(event):
    messagebox.showinfo ('Dữ liệu được chọn', combobox.get())

root = Tk()
root.title('Combobox Demo')
root.geometry('400x200')

values = [f'tháng {i}' for i in range(1,13,1)]
#variable=StringVar()
combobox = ttk.Combobox(root, values = values, textvariable = variable, state = 'read-only')
combobox.pack()
combobox.set(values[1])
#combobox.bind('<<ComboboxSelected>>', selection)

button = Button(root, text = 'Submit')
button.bind('<Button>',selection)
button.pack()
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox

def selection(event):
    messagebox.showinfo ('Dữ liệu được chọn', variable.get())

root = Tk()
root.title('Combobox Demo')
root.geometry('400x200')

values = [f'tháng {i}' for i in range(1,13,1)]
variable=StringVar()
combobox = ttk.Combobox(root, values = values, textvariable = variable, state = 'read-only')
combobox.pack()
combobox.set(values[1])
#combobox.bind('<<ComboboxSelected>>', selection)

button = Button(root, text = 'Submit')
button.bind('<Button>',selection)
button.pack()
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox

def selection(event):
    messagebox.showinfo ('Dữ liệu được chọn', variable.get())

root = Tk()
root.title('Combobox Demo')
root.geometry('400x200')

values = [f'tháng {i}' for i in range(1,13,1)]
variable=StringVar()
#frame = Frame(root, height = 100, width = 200, bd =4)
#frame.pack(side = TOP)
combobox = ttk.Combobox(root, values = values, textvariable = variable, state = 'read-only')
combobox.pack()
combobox.set(values[1])
#combobox.bind('<<ComboboxSelected>>', selection)

button = Button(root, text = 'Submit')
button.bind('<Button>',selection)
button.pack()
root.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
root = Tk()
root.title('Combobox Demo')
root.geometry('400x200')

def selection():
    messagebox.showinfo ('Python course', pythonVariable.get())
    messagebox.showinfo ('Android course', javaVariable.get())
    messagebox.showinfo ('Javascript course', androidVariable.get())

pythonVariable=IntVar()
pythonVariable.set(1)
#Giá trị mặc định là Python course
javaVariable=IntVar()
androidVariable=IntVar()
checkButton1 = Checkbutton(root, text = 'Python (online course)', onvalue =1 , offvalue =0, variable = pythonVariable, command = selection)
checkButton1.place(x=10,y =20)
checkButton2 = Checkbutton(root, text = 'Android (offline course)', onvalue =1 , offvalue =0, variable = javaVariable, command = selection)
checkButton2.place(x=10,y =50)
checkButton3 = Checkbutton(root, text = 'JavaScript (project)', onvalue =1 , offvalue =0, variable = androidVariable, command = selection)
checkButton3.place(x=10,y =80)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title('Combobox Demo')
root.geometry('400x200')

def selection():
    messagebox.showinfo ('Giá trị chọn', f'Bạn chọn giá trị {var1.get()}')
var1= IntVar()
var1.set(2)
#Giá trị mặc định chọn Offline lecture
var2= IntVar()
var3= IntVar()

radiobutton1 = Radiobutton(root, text = 'Online lecture', value = 1, variable = var1, command = selection)
radiobutton1.place(x=10,y =20)
radiobutton2 = Radiobutton(root, text = 'Offline lecture', value = 2, variable = var1, command = selection)
radiobutton2.place(x=10,y =50)
radiobutton3 = Radiobutton(root, text = 'Project lecture',  value = 3, variable = var1, command = selection)
radiobutton3.place(x=10,y =80)
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
root = Tk()
root.title('Menu')
root.geometry('400x300')

def chonmon():
    bunbo= bunboVariable.get()
    phobo= phoboVariable.get()
    phoga= phogaVariable.get()
def soluong_bunbo(event):
    sl_bunbo= int(var_bunbo.get()[0:-5])
def soluong_phobo(event):
    sl_phobo= int(var_phobo.get()[0:-5])
def soluong_phoga(event):
    sl_phoga= int(var_phoga.get()[0:-5])
def httt():
    tt= var1.get()


def thanhtoan(event):
    #if var1 ==1:
    giatien['text']= f'{tongtien}000 VND'
    
lbfont = ('Helvetica','16')
lb_mon = Label(root, text = 'Menu', fg = 'red',  font=lbfont)
lb_mon.place(x=30,y =15)
bunboVariable=IntVar()
phoboVariable=IntVar()
phogaVariable=IntVar()
checkButton1 = Checkbutton(root, text = 'Bún bò: 40000', onvalue =40 , offvalue =0, variable = bunboVariable, command = chonmon)
checkButton1.place(x=10,y =50)
checkButton2 = Checkbutton(root, text = 'Phở bò: 50000', onvalue =50 , offvalue =0, variable = phoboVariable, command = chonmon)
checkButton2.place(x=10,y =80)
checkButton3 = Checkbutton(root, text = 'Phở gà: 45000', onvalue =45 , offvalue =0, variable = phogaVariable, command = chonmon)
checkButton3.place(x=10,y =110)

lb_thanhtoan = Label(root, text = 'Hình thức thanh toán', fg = 'red',  font=lbfont)
lb_thanhtoan.place(x=100,y =140)

var1= IntVar()
radiobutton1 = Radiobutton(root, text = 'Tiền mặt', value = 1, variable = var1, command = httt)
radiobutton1.place(x=10,y =180)
radiobutton2 = Radiobutton(root, text = 'Chuyển khoản (giảm 5%)', value = 2, variable = var1, command = httt)
radiobutton2.place(x=200,y =180)

lb_soluong = Label(root, text = 'Số lượng', fg = 'red',  font=lbfont)
lb_soluong.place(x=225,y =15)

values = [f'{i} phần' for i in range(0,100,1)]
var_bunbo=StringVar()
combobox_bunbo = ttk.Combobox(root, values = values, textvariable = var_bunbo)
combobox_bunbo.place(x=200,y =50)
combobox_bunbo.set(values[0])
combobox_bunbo.bind('<<ComboboxSelected>>', soluong_bunbo)
var_phobo=StringVar()
combobox_phobo = ttk.Combobox(root, values = values, textvariable = var_phobo)
combobox_phobo.place(x=200,y =80)
combobox_phobo.set(values[0])
combobox_phobo.bind('<<ComboboxSelected>>', soluong_phobo)
var_phoga=StringVar()
combobox_phoga = ttk.Combobox(root, values = values, textvariable = var_phoga)
combobox_phoga.place(x=200,y =110)
combobox_phoga.set(values[0])
combobox_phoga.bind('<<ComboboxSelected>>', soluong_phoga)

button = Button(root, text = 'Thanh toán',font= lbfont)
button.bind('<Button>',thanhtoan)
button.place(x=10,y =220)

lb_giatien = Label(root, text = '0 VND', fg = 'red',  font=lbfont)
lb_giatien.place(x=200,y =220)

tongtien = bunbo*sl_bunbo + phobo*sl_phobo + phoga*sl_phoga
giatien['text']= f'{tongtien}000 VND'

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 75>()
#      72 lb_giatien = Label(root, text = '0 VND', fg = 'red',  font=lbfont)
#      73 lb_giatien.place(x=200,y =220)
# ---> 75 tongtien = bunbo*sl_bunbo + phobo*sl_phobo + phoga*sl_phoga
#      76 giatien['text']= f'{tongtien}000 VND'
#      78 root.mainloop()
#
# NameError: name 'bunbo' is not defined

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
root = Tk()
root.title('Menu')
root.geometry('400x300')

def thanhtoan(event):
    bunbo= bunboVariable.get()
    phobo= phoboVariable.get()
    phoga= phogaVariable.get()
    sl_bunbo= int(var_bunbo.get()[0:-5])
    sl_phobo= int(var_phobo.get()[0:-5])
    sl_phoga= int(var_phoga.get()[0:-5])
    tt= var1.get()
    if tt ==1:        
        tongtien = (bunbo*sl_bunbo + phobo*sl_phobo + phoga*sl_phoga)*1000
        lb_giatien['text']= f'{tongtien} VND'
    elif tt ==2:
        tongtien = (bunbo*sl_bunbo + phobo*sl_phobo + phoga*sl_phoga)*0.95*1000
        lb_giatien['text']= f'{tongtien} VND'
    elif bunbo==0 and phobo==0 and phoga==0:
        lb_giatien['text']= 'Bạn chưa chọn món'
    elif sl_bunbo ==0 and sl_phobo ==0 and sl_phoga ==0:
        lb_giatien['text']= 'Bạn chưa nhập \nsố lượng phần'
    else:
        lb_giatien['text']= 'Bạn chưa chọn \nhình thức thanh toán'
lbfont = ('Helvetica','16')
lb_mon = Label(root, text = 'Menu', fg = 'red',  font=lbfont)
lb_mon.place(x=30,y =15)
bunboVariable=IntVar()
phoboVariable=IntVar()
phogaVariable=IntVar()
checkButton1 = Checkbutton(root, text = 'Bún bò: 40000', onvalue =40 , offvalue =0, variable = bunboVariable)
checkButton1.place(x=10,y =50)
checkButton2 = Checkbutton(root, text = 'Phở bò: 50000', onvalue =50 , offvalue =0, variable = phoboVariable)
checkButton2.place(x=10,y =80)
checkButton3 = Checkbutton(root, text = 'Phở gà: 45000', onvalue =45 , offvalue =0, variable = phogaVariable)
checkButton3.place(x=10,y =110)

lb_thanhtoan = Label(root, text = 'Hình thức thanh toán', fg = 'red',  font=lbfont)
lb_thanhtoan.place(x=100,y =140)

var1= IntVar()
radiobutton1 = Radiobutton(root, text = 'Tiền mặt', value = 1, variable = var1)
radiobutton1.place(x=10,y =180)
radiobutton2 = Radiobutton(root, text = 'Chuyển khoản (giảm 5%)', value = 2, variable = var1)
radiobutton2.place(x=200,y =180)

lb_soluong = Label(root, text = 'Số lượng', fg = 'red',  font=lbfont)
lb_soluong.place(x=225,y =15)

values = [f'{i} phần' for i in range(0,100,1)]
var_bunbo=StringVar()
combobox_bunbo = ttk.Combobox(root, values = values, textvariable = var_bunbo)
combobox_bunbo.place(x=200,y =50)
combobox_bunbo.set(values[0])
combobox_bunbo.bind('<<ComboboxSelected>>', soluong_bunbo)
var_phobo=StringVar()
combobox_phobo = ttk.Combobox(root, values = values, textvariable = var_phobo)
combobox_phobo.place(x=200,y =80)
combobox_phobo.set(values[0])
combobox_phobo.bind('<<ComboboxSelected>>', soluong_phobo)
var_phoga=StringVar()
combobox_phoga = ttk.Combobox(root, values = values, textvariable = var_phoga)
combobox_phoga.place(x=200,y =110)
combobox_phoga.set(values[0])
combobox_phoga.bind('<<ComboboxSelected>>', soluong_phoga)

button = Button(root, text = 'Thanh toán',font= lbfont)
button.bind('<Button>',thanhtoan)
button.place(x=10,y =220)

lb_giatien = Label(root, text = '0 VND', fg = 'red',  font=lbfont)
lb_giatien.place(x=200,y =220)

root.mainloop()

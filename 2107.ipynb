# %%
import math
xa=float(input("Nhap hoanh do diem A: "))
ya=float(input("Nhap tung do diem A: "))
xb=float(input("Nhap hoanh do diem B: "))
yb=float(input("Nhap tung do diem B: "))
xc=float(input("Nhap hoanh do diem C: "))
yc=float(input("Nhap tung do diem C: "))
xd=float(input("Nhap hoanh do diem D: "))
yd=float(input("Nhap tung do diem D: "))
#AC là đường chéo
AB=math.sqrt((xb-xa)**2 +(yb-ya)**2)
AD=math.sqrt((xd-xa)**2 +(yd-ya)**2)
BC=math.sqrt((xc-xb)**2 +(yc-yb)**2)
BD=math.sqrt((xd-xb)**2 +(yd-yb)**2)
AC=math.sqrt((xc-xa)**2+(yc-ya)**2)
CD=math.sqrt((xd-xc)**2+(yd-yc)**2)
cosA= (AB**2+AD**2-BD**2)/(2*AB*AD)
cosB= (AB**2+BC**2-AC**2)/(2*AB*BC)
cosC= (BC**2+CD**2-BD**2)/(2*BC*CD)
cosD= (CD**2+AD**2-AC**2)/(2*CD*AD)
A=math.degrees(math.acos(cosA))
B=math.degrees(math.acos(cosB))
C=math.degrees(math.acos(cosC))
D=math.degrees(math.acos(cosD))
print(A,B,C,D)
import turtle
t=turtle.Turtle()
t.shape('turtle')
t.hideturtle()
maunetve=input("Nhap mau net ve: ")
mauto=input("Nhap mau to: ")
t.color(maunetve)
t.fillcolor(mauto)
t.begin_fill()
t.penup()
t.goto(xa,ya)
t.pendown()
t.goto(xb,yb)
t.goto(xc,yc)
t.goto(xd,yd)
t.goto(xa,ya)
t.end_fill()
t=turtle.done()

# %%
import math
xa=float(input("Nhap hoanh do diem A: "))
ya=float(input("Nhap tung do diem A: "))
xb=float(input("Nhap hoanh do diem B: "))
yb=float(input("Nhap tung do diem B: "))
xc=float(input("Nhap hoanh do diem C: "))
yc=float(input("Nhap tung do diem C: "))
xd=float(input("Nhap hoanh do diem D: "))
yd=float(input("Nhap tung do diem D: "))
#phuong trinh duong thang AB co dang: ax+by+c=0
#Vecto phap tuyen duong thang AB:
a=-(yb-ya)
b=xb-xa
#duong thang di qua diem A: 
c= -a*xa-b*ya
#phuong trinh duong thang AC co dang: dx+ey+f=0
#Vecto phap tuyen duong thang AC:
d=-(yc-ya)
e=xc-xa
#duong thang di qua diem A: 
f= -d*xa-e*ya
#phuong trinh duong thang CD co dang: gx+hy+i=0
#Vecto phap tuyen duong thang CD:
g=-(yd-yc)
h=xd-xc
#duong thang di qua diem C:
i=-g*xc-h*yc
j= (g*xa + h*ya +i)==0 or (g*xb + h*yb +i)==0
print(j)
AB=math.sqrt((xb-xa)**2 +(yb-ya)**2)
AC=math.sqrt((xc-xa)**2+(yc-ya)**2)
#AB>AC->AC la canh?
z1= d*xb+e*yb+f
z2= d*xd+e*yd+f
#AC>AB -> AB la canh?
z3=a*xc+b*yc+c
z4=a*xd+b*yd+c
tugiacACDBloi= AB>AC and (z1*z2)>0
tugiacACDBlom=AB>AC and (z1*z2)<0
tugiacABCDloi= AC>AB and (z3*z4)>0
tugiacABCDlom= AC>AB and(z3*z4)<0
#print(z1,z2,z3,z4)
#print(AB,AC)
print("tugiacACDBloi: "+str(tugiacACDBloi))
print("tugiacACDBlom: "+str(tugiacACDBlom))
print("tugiacABCDloi: "+str(tugiacABCDloi))
print("tugiacABCDlom: "+str(tugiacABCDlom))
import turtle
t=turtle.Turtle()
t.shape('turtle')
t.hideturtle()
maunetve=input("Nhap mau net ve: ")
mauto=input("Nhap mau to: ")
t.color(maunetve)
t.fillcolor(mauto)
t.begin_fill()
t.penup()
t.goto(xa,ya)
t.pendown()
t.goto(xb,yb)
t.goto(xc,yc)
t.goto(xd,yd)
t.goto(xa,ya)
t.end_fill()
t=turtle.done()

# %%
import math
xa=float(input("Nhap hoanh do diem A: "))
ya=float(input("Nhap tung do diem A: "))
xb=float(input("Nhap hoanh do diem B: "))
yb=float(input("Nhap tung do diem B: "))
xc=float(input("Nhap hoanh do diem C: "))
yc=float(input("Nhap tung do diem C: "))
xd=float(input("Nhap hoanh do diem D: "))
yd=float(input("Nhap tung do diem D: "))
#phuong trinh duong thang AB co dang: ax+by+c=0
#Vecto phap tuyen duong thang AB:
a=-(yb-ya)
b=xb-xa
#duong thang di qua diem A: 
c= -a*xa-b*ya
#phuong trinh duong thang AC co dang: dx+ey+f=0
#Vecto phap tuyen duong thang AC:
d=-(yc-ya)
e=xc-xa
#duong thang di qua diem A: 
f= -d*xa-e*ya
#phuong trinh duong thang CD co dang: gx+hy+i=0
#Vecto phap tuyen duong thang CD:
g=-(yd-yc)
h=xd-xc
#duong thang di qua diem C:
i=-g*xc-h*yc
if ((g*xa + h*ya +i)==0 or (g*xb + h*yb +i)==0):
    print("khongphaitugiac")
AB=math.sqrt((xb-xa)**2 +(yb-ya)**2)
AC=math.sqrt((xc-xa)**2+(yc-ya)**2)
#AB>AC
if(AB>AC):
    z1= d*xb+e*yb+f
    z2= d*xd+e*yd+f
else:
    z1=a*xc+b*yc+c
    z2=a*xd+b*yd+c
if((z1*z2)>0):
   print("tugiacloi")
elif ((z1*z2)==0):
   print("khongphaitugiac")
else:
   print("tugiaclom")
import turtle
t=turtle.Turtle()
t.shape('turtle')
t.hideturtle()
maunetve=input("Nhap mau net ve: ")
mauto=input("Nhap mau to: ")
t.color(maunetve)
t.fillcolor(mauto)
t.begin_fill()
t.penup()
t.goto(xa,ya)
t.pendown()
t.goto(xb,yb)
t.goto(xc,yc)
t.goto(xd,yd)
t.goto(xa,ya)
t.end_fill()
t=turtle.done()

# %%
import math
xa=float(input("Nhap hoanh do diem A: "))
ya=float(input("Nhap tung do diem A: "))
xb=float(input("Nhap hoanh do diem B: "))
yb=float(input("Nhap tung do diem B: "))
xc=float(input("Nhap hoanh do diem C: "))
yc=float(input("Nhap tung do diem C: "))
xd=float(input("Nhap hoanh do diem D: "))
yd=float(input("Nhap tung do diem D: "))
#phuong trinh duong thang AB co dang: ax+by+c=0
#Vecto phap tuyen duong thang AB:
a=-(yb-ya)
b=xb-xa
#duong thang di qua diem A: 
c= -a*xa-b*ya
#phuong trinh duong thang AC co dang: dx+ey+f=0
#Vecto phap tuyen duong thang AC:
d=-(yc-ya)
e=xc-xa
#duong thang di qua diem A: 
f= -d*xa-e*ya
#phuong trinh duong thang CD co dang: gx+hy+i=0
#Vecto phap tuyen duong thang CD:
g=-(yd-yc)
h=xd-xc
#duong thang di qua diem C:
i=-g*xc-h*yc
if ((g*xa + h*ya +i)==0 or (g*xb + h*yb +i)==0):
    print("khongphaitugiac")
AB=math.sqrt((xb-xa)**2 +(yb-ya)**2)
AD=math.sqrt((xd-xa)**2 +(yd-ya)**2)
BC=math.sqrt((xc-xb)**2 +(yc-yb)**2)
BD=math.sqrt((xd-xb)**2 +(yd-yb)**2)
AC=math.sqrt((xc-xa)**2+(yc-ya)**2)
CD=math.sqrt((xd-xc)**2+(yd-yc)**2)
cosBAD=(AB**2+AD**2-BD**2)/(2*AB*AD)
cosBAC=(AB**2+AC**2-BC**2)/(2*AB*AC)
cosCAD=(AC**2+AD**2-CD**2)/(2*AC*AD)
BAD=math.degrees(math.acos(cosBAD))
BAC=math.degrees(math.acos(cosBAC))
CAD=math.degrees(math.acos(cosCAD))
if((CAD<=(1.0001)*(BAC+BAD))and(CAD>=(0.9999)*(BAC+BAD))):
     z1= d*xb+e*yb+f
     z2= d*xd+e*yd+f
     print("ABladuongcheo")
else:
    z1=a*xc+b*yc+c
    z2=a*xd+b*yd+c
if((z1*z2)>0):
   print("tugiacloi")
elif ((z1*z2)==0):
   print("khongphaitugiac")
else:
   print("tugiaclom")
import turtle
t=turtle.Turtle()
t.shape('turtle')
t.hideturtle()
maunetve=input("Nhap mau net ve: ")
mauto=input("Nhap mau to: ")
t.color(maunetve)
t.fillcolor(mauto)
t.begin_fill()
t.penup()
t.goto(xa,ya)
t.pendown()
t.goto(xb,yb)
t.goto(xc,yc)
t.goto(xd,yd)
t.goto(xa,ya)
t.end_fill()
t=turtle.done()
# Out:
# Nhap hoanh do diem A: 0
# Nhap tung do diem A: 0
# Nhap hoanh do diem B: 100
# Nhap tung do diem B: 150
# Nhap hoanh do diem C: -100
# Nhap tung do diem C: 200
# Nhap hoanh do diem D: -300
# Nhap tung do diem D: 140
# tugiacloi
# Nhap mau net ve: red
# Nhap mau to: green

# %%
number=int(input("Nhap tu 0 den 6: "))
if number == 0:
    print("Monday")
elif number ==1:
    print ("Tuesday")
elif number ==2:
    print ("Wednesday")
elif number ==3:
    print ("Thursday")
elif number ==4:
    print ("Friday")
elif number ==5:
    print ("Saturday")
elif number ==6:
    print ("Sunday")
else:
    print("Input error")

# %%
num=int(input("Nhap so phut goi "))
if num >=0 and num <= 50:
    tien = 25000 + 600*num
    print ("Tien cuoc ",tien)
elif num >=0 and num <=200:
    tien = 25000 + 600*50 + 400*(num-50)
    print ("Tien cuoc ",tien)
elif num >=0 and num >200:
    tien = 25000 + 600*50 + 400*150 +200*(num-200)
    print ("Tien cuoc ",tien)
else:
    print("Error")
# Out:
# Nhap so phut goi -1
# Error

# %%
#BTVN1:
num=float(input("Nhap so dien "))
if num >=0 and num < 51:
    tien = 1678*num
    print ("Tien dien ",tien)
elif num >=0 and num < 101:
    tien = 1678*50 + 1734*(num-50)
    print ("Tien dien ",tien)
elif num >=0 and num < 201:
    tien = 1678*50 + 1734*50 + 2014*(num-100)
    print ("Tien dien ",tien)
elif num >=0 and num < 301:
    tien = 1678*50 + 1734*50 + 2014*100 + 2536*(num-200)
    print ("Tien dien ",tien)
elif num >=0 and num < 401:
    tien = 1678*50 + 1734*50 + 2014*100 + 2536*100 + 2834*(num-300)
    print ("Tien dien ",tien)
elif num >=0 and num >=401:
    tien = 1678*50 + 1734*50 + 2014*100 + 2536*100 + 2834*100 + 2927*(num-400)
    print ("Tien dien ",tien)
else:
    print("Error")
# Out:
# Nhap so dien 101
# Tien dien  172614.0

# %%
#BTVN2:
a=float(input("Nhap he so a "))
b=float(input("Nhap he so b "))
c=float(input("Nhap he so c "))
if a != (-1) and a != 1 and a != 0:
    if b != (-1) and b != 1 and b != 0:
        if c != 0:
            print('{0}x^2 + {1}x + {2} '.format(a,b,c))
        else:
            print('{0}x^2 + {1}x '.format(a,b))
    elif b==(-1):
        if c != 0:
            print('{0}x^2 - x + {1}'.format(a,c))
        else:
            print('{0}x^2 - x '.format(a))
    elif b==1:
        if c != 0:
            print('{0}x^2 + x + {1} '.format(a,c))
        else:
            print('{0}x^2 + x '.format(a))
    else:
        if c != 0:
            print('{0}x^2 + {1} '.format(a,c))
        else:
            print('{0}x^2 '.format(a))
elif a==(-1):
    if b != (-1) and b != 1 and b != 0:
        if c != 0:
            print('-x^2 + {0}x + {1} '.format(b,c))
        else:
            print('-x^2 + {0}x '.format(b))
    elif b==(-1):
        if c != 0:
            print('-x^2 - x + {0} '.format(c))
        else:
            print('-x^2 - x ')
    elif b==1:
        if c != 0:
            print('-x^2 + x + {0} '.format(c))
        else:
            print('-x^2 + x ')
    else:
        if c != 0:
            print('-x^2 + {0} '.format(c))
        else:
            print('-x^2 ')
elif a==1:
    if b != (-1) and b != 1 and b != 0:
        if c != 0:
            print('x^2 + {0}x + {1} '.format(b,c))
        else:
            print('x^2 + {0}x '.format(b))
    elif b==(-1):
        if c != 0:
            print('x^2 - x + {0} '.format(c))
        else:
            print('x^2 - x ')
    elif b==1:
        if c != 0:
            print('x^2 + x + {0} '.format(c))
        else:
            print('x^2 + x ')
    else:
        if c != 0:
            print('x^2 + {0} '.format(c))
        else:
            print('x^2 ')
else:
    if b != (-1) and b != 1 and b != 0:
        if c != 0:
            print('{0}x + {1} '.format(b,c))
        else:
            print('{0}x '.format(b))
    elif b==(-1):
        if c != 0:
            print('-x + {0} '.format(c))
        else:
            print('-x ')
    elif b==1:
        if c != 0:
            print('x + {0} '.format(c))
        else:
            print('x ')
    else:
        if c != 0:
            print('{0} '.format(c))
        else:
            print('phuong trinh vo so nghiem ')
# Out:
# Nhap he so a 1
# Nhap he so b 2
# Nhap he so c 3
# x^2 + 2x + 3

# %%
#BTVN2 27/07:
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
c = int(input("Nhập c: "))

string_a = ""
string_b = ""
string_c = ""

if a != 0:
    if a == 1:
        string_a = "x^2"
    elif a == -1:
        string_a = "-x^2"
    else:
        string_a = f"{a}x^2"
        
if b != 0:
    if b == 1:
        string_b = " + x"
    elif b == -1:
        string_b = " - x"
    elif b > 0:
        string_b = f" + {b}x"
    else:
        string_b = f" - {abs(b)}x"
        
if c != 0:
    if c>0:
        string_c = f" + {abs(c)}"
    else:
        string_c = f" - {abs(c)}"
        
print (f"Phương trình vừa nhập: {string_a}{string_b}{string_c}")

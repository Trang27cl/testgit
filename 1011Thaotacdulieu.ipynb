# %%
import pandas as pd
students = pd.read_csv(r'C:\Users\Admin\resources\students.csv',encoding = 'utf-8')
students
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam      Hà Nội   5.6  7.0
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# 8     20205218  Nguyễn Văn Thành   5/20/2000       Nam      Hà Nội   7.0  7.4
# 9     20205219  Nguyễn Thanh Oai   5/25/2000       Nam      Hà Nội   8.2  7.0
#
#    Hoá  Sinh  Văn  Sử   Địa  Tiếng Anh
# 0  8.8   6.8  4.0  5.4  5.6        8.5
# ...

# %%
#Lọc bởi chỉ số cột và chỉ số dòng
#Lọc các cột,fancy index (index là một list)
students[['Toán','Lý','Hoá','Sinh','Sử ','Địa']]

# %%
#Lọc theo cột
#Toàn bộ cột từ 5 trở đi, dùng slicing
students[students.columns[5:]]

# %%
#Lọc dữ liệu theo dòng, theo index hoặc chỉ số ngầm định/ tường minh (loc và iloc)
students.loc[1:5]

# %%
#Lọc dữ liệu theo cột và dòng
students[students.columns[5:]][:4]

# %%
#Lọc dữ liệu theo cột và dòng
#lấy 3 dòng đầu tiên của 2 cột đầu
#chỉ số trước là dong, chỉ số sau là cột
students.iloc[:3,:2]

# %%
#Lọc bằng phương thức filter
students.filter(['Toán','Lý','Hoá'])

# %%
students.filter(students.columns[5:])

# %%
#Lọc các dòng rời rạc
students.filter([0,1,3,4,7],axis = 0)
#axis không có -> mặc định là 1 -> lọc theo cột mà không có cột 0,1,3,5,7 ->lỗi

# %%
students.index[students.index%2!=0]

# %%
students.filter(students.index[students.index%2!=0],axis=0)

# %%
#Lọc theo cột và dòng
students.filter(['Toán','Lý','Hoá'])[:5]

# %%
#Lọc theo cột và dòng
students.filter(['Toán','Lý','Hoá']).loc[:5]

# %%
#lọc có điều kiện
#Lọc theo điều kiện đơn
#Các toán tử có thể dùng: ==,>,<.<=,>=.!=...
students[students['Toán']>7]

# %%
#Lọc theo nhiều điều kiện
# & - và, | - hoặc ,~ - phủ định
students[(students['Toán']>7) & (students['Văn']>=6.5)]

# %%
students[~((students['Toán']>7) & (students['Văn']>=6.5))]

# %%
students[(students['Toán']<=7) | (students['Văn']<6.5)]

# %%
#Lọc có điều kiện bằng phương thức query (truy vấn:query)
#cho kết quả nhanh hơn
students.query('Toán > 7 and Văn >=6.5')

# %%
students.query('Toán > 7 and not Văn >=6.5')

# %%
#Gom nhóm dữ liệu
students.groupby('Quê quán')['Toán'].mean()

# %%
#Gom nhóm dữ liệu
students.groupby(['Quê quán','Giới tính'])['Toán'].mean()

# %%
#Sinh dữ liệu từ các cột dữ liệu
students ['Đtb']= round((2*(students['Toán']+students['Văn']+students['Tiếng Anh'])+(students['Sử ']+students['Địa']+students['Lý']+students['Hoá']+ students['Sinh']))/11)
students
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam      Hà Nội   5.6  7.0
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# 8     20205218  Nguyễn Văn Thành   5/20/2000       Nam      Hà Nội   7.0  7.4
# 9     20205219  Nguyễn Thanh Oai   5/25/2000       Nam      Hà Nội   8.2  7.0
#
#    Hoá  Sinh  Văn  Sử   Địa  Tiếng Anh  Đtb
# 0  8.8   6.8  4.0  5.4  5.6        8.5  7.0
# ...

# %%
#students ['ĐH khối A']= (students['Toán']+students['Lý']+students['Hoá'])>=23.5
#students

# %%
import numpy as np
students['ĐH khối A']=np.where((students['Toán']+students['Lý']+\
                                 students['Hoá'])>23.5,'Đỗ','Trượt')
students['ĐH khối A1']=np.where((students['Toán']+students['Lý']+\
                                 students['Tiếng Anh'])>22,'Đỗ','Trượt')
students['ĐH khối B']=np.where((students['Toán']+students['Lý']+\
                                 students['Tiếng Anh'])>21.5,'Đỗ','Trượt')
students['ĐH khối C']=np.where((students['Văn']+students['Sử ']+\
                                 students['Địa'])>22.5,'Đỗ','Trượt')
students['ĐH khối D']=np.where((students['Toán']+students['Văn']+\
                                 2*(students['Tiếng Anh']))>27.5,'Đỗ','Trượt')

students
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam      Hà Nội   5.6  7.0
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# 8     20205218  Nguyễn Văn Thành   5/20/2000       Nam      Hà Nội   7.0  7.4
# 9     20205219  Nguyễn Thanh Oai   5/25/2000       Nam      Hà Nội   8.2  7.0
#
#    Hoá  Sinh  Văn  Sử   Địa  Tiếng Anh  Đtb ĐH khối A ĐH khối A1 ĐH khối B  \
# ...

# %%
#nhiều lựa chọn sử dụng np.select
xs = students['Toán']>=9
gioi = (students['Toán']>=8.0) &(students['Toán']<9)
kha = (students['Toán']>=7.0) &(students['Toán']<8)
tb = (students['Toán']>=5.0) &(students['Toán']<7)
conditions = [xs, gioi, kha, tb]
xl = ['Xuất sắc', 'Giỏi', 'Khá', 'Trung bình']
students['XL Toán'] = np.select(conditions, xl,default='Kém')
students

# %%
#Tách cột
students['Họ']= students['Họ tên'].str.split().str[0]
students

# %%
students[students['Họ']=='Nguyễn']

# %%
students['Họ tên'].str.index(' ')+1

# %%
students['Họ tên'].str[3:]

# %%
#Tách cột có dữ liệu kiểu thời gian
import datetime
students['Ngày']= pd.to_datetime(students['Ngày sinh']).dt.day
students['Tháng']= pd.to_datetime(students['Ngày sinh']).dt.month
students['Năm']= pd.to_datetime(students['Ngày sinh']).dt.year
students
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam      Hà Nội   5.6  7.0
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# 8     20205218  Nguyễn Văn Thành   5/20/2000       Nam      Hà Nội   7.0  7.4
# 9     20205219  Nguyễn Thanh Oai   5/25/2000       Nam      Hà Nội   8.2  7.0
#
#    Hoá  Sinh  Văn  ...  Tiếng Anh  Đtb  ĐH khối A  ĐH khối A1 ĐH khối B  \
# ...

# %%
students.groupby('Năm')['Năm'].count()
# Out:
# Năm
# 2000    8
# 2001    1
# 2002    1
# Name: Năm, dtype: int64

# %%
students[(students['ĐH khối A']=='Trượt') & (students['ĐH khối A1']=='Trượt') & (students['ĐH khối B']=='Trượt') &(students['ĐH khối C']=='Trượt') & (students['ĐH khối D']=='Trượt')]
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính   Quê quán  Toán   Lý  \
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ     Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ   Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam  Thái Bình   9.3  5.8
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam     Hà Nội   5.6  7.0
#
#    Hoá  Sinh  Văn  ...  Tiếng Anh  Đtb  ĐH khối A  ĐH khối A1 ĐH khối B  \
# 2  5.4   8.0  7.0  ...        5.5  6.0      Trượt       Trượt     Trượt
# 3  6.5   7.0  7.5  ...        6.0  7.0      Trượt       Trượt     Trượt
# 4  7.5   4.5  6.5  ...        3.8  6.0      Trượt       Trượt     Trượt
# 5  5.6   5.0  6.4  ...        4.9  6.0      Trượt       Trượt     Trượt
#
#   ĐH khối C ĐH khối D Ngày Tháng   Năm
# 2     Trượt     Trượt    5     7  2002
# 3     Trượt     Trượt   17    12  2000
# 4     Trượt     Trượt   25     1  2000
# 5     Trượt     Trượt    3     4  2000
#
# ...

# %%
passA = students[(students['ĐH khối A']=='Đỗ') | (students['ĐH khối A1']=='Đỗ')]
passA.groupby(['Quê quán','Giới tính'])['ĐH khối A','ĐH khối A1'].count()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12400\542905640.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   passA.groupby(['Quê quán','Giới tính'])['ĐH khối A','ĐH khối A1'].count()
#                       ĐH khối A  ĐH khối A1
# Quê quán   Giới tính
# Bắc Ninh   Nam                1           1
# Hà Nội     Nam                3           3
# Quảng Bình Nam                1           1

# %%
students['gradegroupA']= students['Toán']+students['Lý']+students['Hoá']
uniH=students[students['gradegroupA']>=18.5]
đk=[(uniH['gradegroupA']>=23) & (uniH['Toán']>=8)]
xl_class=['Đỗ']
uniH['TalentClass']=np.select(đk,xl_class,default='Trượt')
uniH
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12400\734324352.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uniH['TalentClass']=np.select(đk,xl_class,default='Trượt')
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# ...

# %%
sort_students=students.sort_values(by='Họ tên')
sort_students
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 7     20205217   Hoàng Trung Sơn   8/27/2000       Nam    Bắc Ninh   7.5  9.0
# 5     20205215     Hà Trung Kiên    4/3/2000       Nam      Hà Nội   5.6  7.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 9     20205219  Nguyễn Thanh Oai   5/25/2000       Nam      Hà Nội   8.2  7.0
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 8     20205218  Nguyễn Văn Thành   5/20/2000       Nam      Hà Nội   7.0  7.4
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 6     20205216      Võ Hoàng Yến   6/21/2000        Nữ    Nam Định   6.7  6.8
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
#
#    Hoá  Sinh  Văn  ...  Đtb  ĐH khối A  ĐH khối A1  ĐH khối B ĐH khối C  \
# ...
